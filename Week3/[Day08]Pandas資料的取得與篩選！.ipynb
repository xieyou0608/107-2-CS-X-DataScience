# %%
import pandas as pd
import numpy as np

memberData = pd.read_csv('Member.csv', dtype = {'IsInBlackList' : object})
#篩選出男性的資料
male = (memberData['GenderTypeDef'] == 'Male')
#篩選出註冊方式為Web的資料
web = (memberData['RegisterSourceTypeDef'] == 'Web')
#列出為男性且用Web註冊的資料
memberData[(male & web)]
# Out:
#         MemberId    Birthday GenderTypeDef RegisterSourceTypeDef  \
# 9181      217820  1991-10-02          Male                   Web
# 9725     3297579  1980-07-08          Male                   Web
# 9953      982794  2017-11-04          Male                   Web
# 9998     6106042  1983-05-28          Male                   Web
# 10903    2566385  1981-01-20          Male                   Web
# 10913    5924304  1985-07-29          Male                   Web
# 11057    4137028  1995-10-07          Male                   Web
# 11142    5349111  1992-08-08          Male                   Web
# 11181    5385585  1987-03-26          Male                   Web
# 11813      80288  1986-03-12          Male                   Web
# 13229    4022412  2002-02-23          Male                   Web
# 13594    5966557  1993-11-26          Male                   Web
# 14098    2402768  1990-02-04          Male                   Web
# ...
